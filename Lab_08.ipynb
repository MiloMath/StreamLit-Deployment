# %%
from openai import OpenAI
import pandas as pd
import transformers as tf
import streamlit as st
import os

# %%
df = pd.read_csv("music_dataset.csv")
os.environ['OPENAI_API_KEY'] = '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'

# %%
df
# Out:
#                 track_name             artist_name         genre  year  tempo  \
# 0          Echoes of Light       Sixty Miles Ahead          Folk  1992    172
# 1           Motion of Time          Broke For Free         Blues  1995    132
# 2       Colors from Within                 Jahzzar          Soul  1975     98
# 3        Dreams in Shadows       Sixty Miles Ahead        Reggae  1973    130
# 4         Midnight of Time               Lobo Loco          Jazz  1978    153
# ..                     ...                     ...           ...   ...    ...
# 245  Reflections in Motion       Sixty Miles Ahead  Instrumental  2003     89
# 246        Lost of the Sea         Chris Zabriskie       Country  1973    179
# 247         Motion in Blue                 Fleslit          Soul  2021    167
# 248        Voices of Light  Unheard Music Concepts    Electronic  1977    113
# 249    Midnight in Shadows               Crowander  Instrumental  1998    119
#
# ...

# %%
# Convertir la tabla a una representación de cadena (string)
music_string = df.to_string()

question = "¿A qué género debo destinar más recursos de publicidad tomando en cuenta la representación en la base de datos?"

# Pasar la variable al API de OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "Do not answer any question that is not about the topic of Music. You are a Here is the data:\n" + df_string},
        {"role": "user", "content": question}
    ]
)

# Obtener la respuesta del API
answer = response.choices[0].message.content
print(answer)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Milo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
# ...
